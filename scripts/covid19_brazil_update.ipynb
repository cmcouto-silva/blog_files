# %%
import pandas as pd

# %%
df = pd.read_csv('https://data.brasil.io/dataset/covid19/caso_full.csv.gz')

# %%
df = df[(df.is_last) & (df.place_type=='state')]
# Out:
#        city  city_ibge_code        date  epidemiological_week  \
# 108715  NaN            16.0  2020-05-22                    21
# 108731  NaN            24.0  2020-05-22                    21
# 108738  NaN            17.0  2020-05-22                    21
# 112566  NaN            12.0  2020-05-23                    21
# 112567  NaN            27.0  2020-05-23                    21
# 112568  NaN            13.0  2020-05-23                    21
# 112570  NaN            29.0  2020-05-23                    21
# 112571  NaN            23.0  2020-05-23                    21
# 112572  NaN            53.0  2020-05-23                    21
# 112573  NaN            32.0  2020-05-23                    21
# 112574  NaN            52.0  2020-05-23                    21
# 112575  NaN            21.0  2020-05-23                    21
# 112577  NaN            50.0  2020-05-23                    21
# 112578  NaN            51.0  2020-05-23                    21
# ...
